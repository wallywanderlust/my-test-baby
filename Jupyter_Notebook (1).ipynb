# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Walter Hampton**
# <br>
# Data Analyst

# %% [markdown]
# *I am interested in data science because I love mathematics and working with numbers. Being able*
# <br>
# *to come up with solutions for a business' pain points is something that is really rewarding*
# <br>
# *I also love sports and would one day love to get a job in analytics for a sports betting company.*

# %% [markdown]
# ### My code is going to multiply the number 36 by the number 24.

# %%
36 * 24
# Out:
# 864

# %% [markdown]
# ![il_1588xN.4101130354_3kwe.jpg](attachment:9e2cbfe4-eb1f-4b48-a9f2-9ed86a3be39d.jpg)
# <br>
# - Reasons why I like this picture
#     1. It's funny
#     2. The mug looks nice
#     3. It's relevant to data analytics
#
# - Reasons not to like this mug
#     1. ~It's not funny~
#     2. ~The mug is ugly~
#     3. ~It's not relevant to anyone~
